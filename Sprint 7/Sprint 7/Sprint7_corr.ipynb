# %% [markdown]
# <font color='#cb8ce1'>**SPRINT 7 - ANABEL MARTÍNEZ**</font>
#
# <font color='#DA007F'>**NIVELL 1**</font>
#
# <font color='#DA007F'>**Exercici 1**</font>
#
# **Calculadora de l'índex de massa corporal**
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades.
#
# La funció ha de classificar el resultat en les seves respectives categories

# %%
def pedir_datos():
    altura = float(input("Altura del usuario en metros."))
    peso = float(input("Peso del usuario."))
    return altura, peso

def calculadora_IMC():

    altura, peso = pedir_datos()
    
    IMC = round(peso/(altura*altura), 2)
    
    if IMC <= 18.5: 
        return(f"El usuario tiene un IMC de {IMC}, lo que se considera bajo peso.")
    elif IMC <= 24.9:
        return(f"El usuario tiene un IMC de {IMC}, lo que se considera un peso normal.")
    elif IMC < 29.9:
        return(f"El usuario tiene un IMC de {IMC}, lo que se considera sobrepeso.")
    else:
        return(f"El usuario tiene un IMC de {IMC}, lo que se considera obesidad.")

# %%
calculadora_IMC()
# Out:
# 'El usuario tiene un IMC de 24.49, lo que se considera un peso normal.'

# %% [markdown]
# <font color='#DA007F'>**Exercici 2**</font>
#
#  **Convertidor de temperatures.**
#
#  Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C),
#  Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re). Selecciona almenys 2 conversors,
#  de tal manera que en introduir una temperatura retorni, com a mínim, dues conversions

# %%
def conversion_temperaturas():
    valor = float(input("¿Qué temperatura deseas convertir? En número.")) 
    unidad = input("¿Qué unidad es? C para Celsius, F para Fahrenheit o K para Kelvin:").upper() 

    if unidad == "C":
        dict_celsius ={ 
            'cel-fahr': round((valor * 9/5) + 32, 2), 
            'cel-kel': round(valor + 273.15, 2) 
        }
        return(f"Has introducido {valor} ºC, que son {dict_celsius['cel-fahr']} ºF y {dict_celsius['cel-kel']} K.")
    elif unidad == "F": 
        dict_fahrenheit ={
            'fahr-cel': round((valor - 32) * 5/9, 2), 
            'fahr-kel': round((valor - 32) * 5/9 + 273.15, 2)}

        return(f"Has introducido {valor} ºF, que son {dict_fahrenheit['fahr-cel']} ºC y {dict_fahrenheit['fahr-kel']} K.")

    elif unidad == "K":
        dict_kelvin ={
            'kel-cel': round(valor - 273.15, 2),
            'kel-fahr': round((valor - 273.15) * 9/5 + 32, 2)}

        return(f"Has introducido {valor} K, que son {dict_kelvin['kel-cel']} ºC y {dict_kelvin['kel-fahr']} ºF.")

# %%
conversion_temperaturas()
# Out:
# 'Has introducido 30.0 ºC, que son 86.0 ºF y 303.15 K.'

# %% [markdown]
# <font color='#DA007F'>**Exercici 3**</font>
#
# **Comptador de paraules d'un text.**
#
# Escriu una funció que donat un text, mostri les vegades que apareix cada paraula

# %% [markdown]
# ```python
# def contador_palabras(texto=None):
#     if texto is None:
#         texto = input("Escribe el texto a analizar.")
#
# #En este caso, he utilizado la opción del condicional para poder reutilizar la función con textos que no provengan solo de inputs.
#
# ```

# %%
def contador_palabras(texto=None):
    if texto is None:
        texto = input("Escribe el texto a analizar.")
    
    ContadorPal = {}
    
    for palabra in texto.split():
        palabra = palabra.lower().strip(".,()¿?¡!;:")
        if palabra not in ContadorPal:
            ContadorPal[palabra] = 1
        else:
            ContadorPal[palabra] += 1 
    
    return(ContadorPal)

# %%
contador_palabras()

#Texto ejemplo para utilizar: El Vincent es mi perro y es el perro más bonito sobre cualquier otro perro del mundo incluido mi perro que es el Vincent
# Out:
# {'hola': 1, 'que': 1, 'tal': 1}

# %% [markdown]
# <font color='#DA007F'>**Exercici 4**</font>
#
#  **Diccionari invers.**
#
#
#  Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviats les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment.
#
#
# reverse_dictionary({"a": 1, "b": 2, "c": 3})
#
# {1: 'a', 2: 'b', 3: 'c'}
#
# reverse_dictionary({'x': 'apple', 'y': 'banana', 'z': 'banana'})
#
# Error: multiple keys for one value

# %% [markdown]
# ```python
# # He decidido cambiar mi código anterior de:
#             return "Error: varias claves con un mismo valor."
# # a:
#             raise ValueError("Error: varias claves con un mismo valor.")
# # para poder reutilizar la función.
# ```

# %%
def invertir_dic(diccionario_a_invertir):

    dic_invertido = {}

    for clave, valor in diccionario_a_invertir.items():

        if valor in dic_invertido:
            raise ValueError("Error: varias claves con un mismo valor.")

        dic_invertido[valor] = clave

    return dic_invertido

# %%
reverse_dictionary = {"a": 1, "b": 2, "c": 3}

invertir_dic(reverse_dictionary)
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
reverse_dictionary2 = {"x": "apple", "y": "banana", "z": "banana"}

invertir_dic(reverse_dictionary2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 reverse_dictionary2 = {"x": "apple", "y": "banana", "z": "banana"}
# ----> 3 invertir_dic(reverse_dictionary2)
#
# Cell In[9], line 8, in invertir_dic(diccionario_a_invertir)
#       5 for clave, valor in diccionario_a_invertir.items():
#       7     if valor in dic_invertido:
# ----> 8         raise ValueError("Error: varias claves con un mismo valor.")
#      10     dic_invertido[valor] = clave
#      12 return dic_invertido
#
# ValueError: Error: varias claves con un mismo valor.

# %% [markdown]
# <font color='#DA007F'>**NIVELL 2**</font>
#
# <font color='#DA007F'>**Exercici 1**</font>
#
# **Diccionari invers amb duplicats**
#
# Continuant amb l'exercici 4 del nivell 1: al client es va oblidar de comentar un detall i resulta que els valors en el diccionari original poden duplicar-se i més, per la qual cosa les claus intercanviades poden tenir duplicats. En aquest cas, en l'exercici anterior imprimies un missatge d'advertiment, ara, els valors del diccionari resultant hauran d'emmagatzemar-se com una llista. Tingues en compte que si és un valor únic no ha de ser una llista.
#
# reverse_dictionary_plus({'x': 'apple', 'y': 'banana', 'z': 'banana'})
# {'apple': 'x', 'banana': ['y', 'z']}

# %%
def invertir_dic2(diccionario_a_invertir):
    try:
        return invertir_dic(diccionario_a_invertir)
    except ValueError:
        dic_invertido3 = {}

        for clave, valor in diccionario_a_invertir.items():
            if valor in dic_invertido3:
                if isinstance(dic_invertido3[valor], list):
                    dic_invertido3[valor].append(clave)
                else:
                    dic_invertido3[valor] = [dic_invertido3[valor], clave]
            else:
                dic_invertido3[valor] = clave

        return dic_invertido3

# %%
reverse_dictionary_plus = {'x': 'apple', 'y': 'banana', 'z': 'banana', 'a': 'banana', 'b': 'banana'}

invertir_dic2(reverse_dictionary_plus)
# Out:
# {'apple': 'x', 'banana': ['y', 'z', 'a', 'b']}

# %% [markdown]
# <font color='#DA007F'>**Exercici 2**</font>
#
# **Conversió de tipus de dades**
#
# El client rep una llista de dades i necessita generar dues llistes, la primera on estaran tots els elements que es van poder convertir en flotants i l'altra on estan els elements que no es van poder convertir. Exemple de la llista que rep el client: [ '1.3', 'one' , '1e10' , 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']]
#
# conversion([ '1.3', 'one' , '1e10' , 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']])
# ([1.3, 1000000000.0, 2.0, 1.0, 1.4, 1.0, 2.0, 3.0, 3.4],
# ['one, 'seven', '3-1/2', 'not-a-number])

# %%
def separar_floats_nofloats(lista):

    floats = []
    lista_otros = []

    for dato in lista:

        if isinstance(dato, (list, tuple)):
            for x in dato: 
                try: 
                    floats.append(float(x))
                except: 
                    lista_otros.append(x)  
        else: 
            try:
                floats.append(float(dato)) 
            except:
                lista_otros.append(dato)  
                
    return floats, lista_otros

# %%
lista_inicial = [ '1.3', 'one' , '1e10' , 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']]

separar_floats_nofloats(lista_inicial)
# Out:
# ([1.3, 10000000000.0, 2.0, 1.0, 1.4, 1.0, 2.0, 3.0, 3.4],
#  ['one', 'seven', '3-1/2', 'not-a-number'])

# %% [markdown]
# <font color='#DA007F'>**NIVELL 3**</font>
#
# <font color='#DA007F'>**Exercici 1**</font>
#
# **Comptador i endreçador de paraules d'un text.**
#
# El client va quedar content amb el comptador de paraules, però ara vol llegir arxius TXT i que calculi la freqüència de cada paraula ordenades dins de les entrades habituals del diccionari segons la lletra amb la qual comencen, és a dir, les claus han d'anar de la A a la Z i dins de la A hem d'anar de la A la Z. Per exemple, per a l'arxiu "tu_me_quieres_blanca.txt" la sortida esperada seria:

# %%
def contar_ordenar(ruta_archivo):

    with open(ruta_archivo, encoding="utf-8") as mequieres:
        texto = mequieres.read()

    clasificadas_ordenadas = dict(sorted(contador_palabras(texto).items()))

    diccionario_clasificado = {}
    for palabra, cantidad in clasificadas_ordenadas.items():
        if palabra:
            first_letter = palabra[0].lower()
            if first_letter not in diccionario_clasificado:
                diccionario_clasificado[first_letter] = {}
            diccionario_clasificado[first_letter][palabra] = cantidad

    return diccionario_clasificado

# %%
contar_ordenar("tu_me_quieres_blanca.txt")
# Out:
# {'a': {'a': 3,
#   'agua': 1,
#   'al': 2,
#   'alba': 4,
#   'alcobas': 1,
#   'alimenta': 1,
#   'alma': 1,
#   'amarga': 1,
#   'azucena': 1},
#  'b': {'baco': 1,
#   'banquete': 1,
#   'bebe': 1,
#   'blanca': 3,
#   'boca': 1,
#   'bosques': 1,
#   'buen': 1},
#  'c': {'cabañas': 1,
#   'carnes': 2,
#   'casta': 3,
#   'cerrada': 1,
#   'con': 4,
#   'conservas': 1,
#   'copas': 1,
#   'corola': 1,
#   'corriste': 1,
#   'cuando': 2,
#   'cubierto': 1,
#   'cuerpo': 1,
#   'cuáles': 1},
#  'd': {'de': 8, 'dejaste': 1, 'del': 1, 'diga': 1, 'dios': 2, 'duerme': 1},
#  'e': {'el': 4,
#   'ellas': 1,
#   'en': 4,
#   'engaño': 1,
#   'enredada': 1,
#   'entonces': 1,
#   'escarcha': 1,
#   'espumas': 1,
#   'esqueleto': 1,
#   'estrago': 1},
#  'f': {'festejando': 1, 'filtrado': 1, 'frutos': 1},
#  'h': {'habla': 1,
#   'hacia': 1,
#   'haya': 1,
#   'hayas': 1,
#   'hermana': 1,
#   'hombre': 1,
#   'hubiste': 1,
#   'huye': 1},
#  'i': {'intacto': 1},
#  'j': {'jardines': 1},
# ...
